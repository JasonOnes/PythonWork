# %%
import csv
import pandas as pandas
#def find_art(x):
    #x = input("Where are you?">> )
#with open('/home/jasonones/Git/PythonFullStack/1_Python/labs/objects/public_art/public_art.csv') as taco:
    #art = csv.DictReader(taco)

    #print(art)
df = pandas.read_csv('/home/jasonones/Git/PythonFullStack/1_Python/labs/objects/public_art/public_art.csv', encoding="latin-1") #names = ['record_id', 'artist', 'title', 
#'date', 'medium', 'discipline', 'dimensions',
                                                                                                              #        'funding_source', 'location', 'street', 
                                                                                                               #    'city', 'state', 'zipcode', 'lat', 'lng',
                                                                                                            #        'description', 'image_url', 'detail_url', 
                                                                                                                 #     'date_mdified'], encoding="latin-1")

                
                
                
df
# Out:
#      record_id                                             artist  \
# 0            5                                      Richard Rezac
# 1          317                                          Vern Luce
# 2          359                                         Bruce West
# 3          362                                        Jerry Allen
# 4          470                                        Carl Morris
# 5          585                                        John Rogers
# 6          617                                      Charles Kibby
# 7          622                                    Connie Earnshaw
# 8          632                                        Hank Kowert
# 9          633                                   Manuel Izquierdo
# 10         762                                         Bruce West
# 11         763                                     Gregory Grenon
# 12         764  Alice Van Leunen, Susanna Kuo, Nexus (Susanna ...
# ...

# %%
pandas.DataFrame(df['lat']),(df['lng'])
# Out:
# (                    lat
#  0                   lat
#  1    45.512403499999998
#  2    45.536000000000001
#  3    45.501564199999997
#  4    45.568221899999998
#  5    45.512731000000002
#  6    45.519571399999997
#  7    45.470452900000019
#  8    45.589981999999999
#  9    45.512613700000003
#  10   45.512610100000003
#  11   45.512610100000003
#  12   45.512613700000003
#  13   45.512613700000003
#  14   45.512610100000003
#  15   45.512610100000003
#  16   45.512613700000003
#  17   45.512613700000003
#  18   45.512610100000003
#  19   45.512610100000003
#  20   45.512469099999997
#  21   45.512731000000002
#  22   45.512610100000003
#  23   45.512610100000003
#  24   45.512613700000003
#  25   45.528219300000003
#  26   45.515248999999997
#  27   45.515248999999997
#  28   45.515248999999997
#  29   45.515248999999997
#  ..                  ...
#  518  45.595809600000003
#  519                 NaN
#  520  45.511517900000001
#  521  45.511502499999999
#  522  45.526343999999987
# ...

# %%
df
# Out:
#      record_id                                             artist  \
# 0    record_id                                             artist
# 1            5                                      Richard Rezac
# 2          317                                          Vern Luce
# 3          359                                         Bruce West
# 4          362                                        Jerry Allen
# 5          470                                        Carl Morris
# 6          585                                        John Rogers
# 7          617                                      Charles Kibby
# 8          622                                    Connie Earnshaw
# 9          632                                        Hank Kowert
# 10         633                                   Manuel Izquierdo
# 11         762                                         Bruce West
# 12         763                                     Gregory Grenon
# ...

# %%
long_lat = zip(df['lat'],df['lng'])
print(long_lat)

# %%
from pandas import *

dfList_lat = df['lat'].tolist()
dfList_lng = df['lng'].tolist()
lat_long = zip(dfList_lat, dfList_lng)
print(lat_long)
#print(dfList_lat)
